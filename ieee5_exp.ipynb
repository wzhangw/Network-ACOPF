# %%
using PowerModels, Gurobi, Ipopt, JuMP, COSMO, Mosek, MosekTools, MathOptInterface
const MOI = MathOptInterface
# Out:
# MathOptInterface

# %%
file = "case5.m"
# Out:
# "case5.m"

# %%
# Ipopt for polar ACOPF
ipopt_polar = run_ac_opf(file, Ipopt.Optimizer)
# Out:
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 4 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 4 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 3 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 3 from 360.0 to 60.0 deg.
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      155
# Number of nonzeros in inequality constraint Jacobian.:       32
# Number of nonzeros in Lagrangian Hessian.............:      248
#
# Total number of variables............................:       44
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       23
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       35
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:        6
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       10
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0059989e+02 3.99e+00 2.88e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  8.2813514e+03 2.47e+00 1.02e+02  -1.0 2.80e+00    -  4.05e-03 3.82e-01h  1
#    2  6.2768298e+03 2.38e+00 9.84e+01  -1.0 2.75e+01    -  5.24e-02 3.43e-02f  1
#    3  5.8720445e+03 2.32e+00 9.46e+01  -1.0 2.05e+01    -  3.11e-01 2.71e-02f  1
#    4  5.4813618e+03 2.08e+00 8.36e+01  -1.0 1.59e+01    -  3.52e-01 1.03e-01f  1
#    5  7.9461167e+03 1.19e+00 4.69e+01  -1.0 1.00e+01    -  8.15e-01 4.26e-01h  1
#    6  8.1547941e+03 1.16e+00 4.87e+01  -1.0 1.03e+01    -  1.10e-01 3.15e-02h  1
#    7  9.2437483e+03 1.02e+00 4.26e+01  -1.0 2.97e+00    -  5.04e-03 1.18e-01h  1
#    8  1.4202836e+04 4.11e-01 1.75e+01  -1.0 2.89e+00    -  7.23e-01 5.96e-01h  1
#    9  1.7482548e+04 1.18e-02 4.47e+00  -1.0 1.11e+00    -  7.70e-01 9.71e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.7586439e+04 5.85e-04 1.60e+00  -1.0 3.31e-01    -  1.00e+00 1.00e+00h  1
#   11  1.7587689e+04 3.99e-05 1.23e-01  -1.0 9.61e-02    -  1.00e+00 1.00e+00h  1
#   12  1.7558053e+04 4.39e-03 3.88e-01  -2.5 2.31e-01    -  8.73e-01 9.48e-01f  1
#   13  1.7553095e+04 3.85e-03 5.02e+00  -2.5 7.27e-02    -  1.00e+00 7.89e-01h  1
#   14  1.7552947e+04 2.47e-05 8.84e-03  -2.5 1.58e-02    -  1.00e+00 1.00e+00h  1
#   15  1.7551986e+04 1.34e-05 9.92e-01  -3.8 1.18e-02    -  1.00e+00 9.29e-01f  1
#   16  1.7551938e+04 4.36e-08 1.15e-02  -3.8 3.69e-03    -  1.00e+00 1.00e+00f  1
#   17  1.7551940e+04 1.98e-10 1.78e-04  -3.8 2.03e-04    -  1.00e+00 1.00e+00h  1
#   18  1.7551892e+04 1.73e-07 2.11e-01  -5.7 1.33e-03    -  1.00e+00 9.68e-01f  1
#   19  1.7551891e+04 6.77e-11 3.08e-05  -5.7 1.33e-04    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.7551891e+04 8.68e-14 6.51e-10  -5.7 3.00e-07    -  1.00e+00 1.00e+00h  1
#   21  1.7551891e+04 5.92e-12 3.02e-07  -8.6 1.90e-05    -  1.00e+00 1.00e+00f  1
#   22  1.7551891e+04 5.97e-14 1.99e-12  -8.6 1.91e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 22
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.3879727096486954e+02    1.7551890838594780e+04
# Dual infeasibility......:   1.9906949443685931e-12    7.9627797774743723e-11
# Constraint violation....:   3.8609471175732322e-14    5.9729998724833422e-14
# Complementarity.........:   2.5059076176708660e-09    1.0023630470683464e-07
# Overall NLP error.......:   2.5059076176708660e-09    1.0023630470683464e-07
#
#
# Number of objective function evaluations             = 23
# Number of objective gradient evaluations             = 23
# Number of equality constraint evaluations            = 23
# Number of inequality constraint evaluations          = 23
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 23
# Number of Lagrangian Hessian evaluations             = 22
# Total CPU secs in IPOPT (w/o function evaluations)   =      2.074
# Total CPU secs in NLP function evaluations           =      1.304
#
# EXIT: Optimal Solution Found.
# Dict{String,Any} with 8 entries:
#   "solve_time"         => 3.82597
#   "optimizer"          => "Ipopt"
#   "termination_status" => LOCALLY_SOLVED
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 17551.9
#   "solution"           => Dict{String,Any}("baseMVA"=>100,"branch"=>Dict{String…
#   "objective_lb"       => -Inf

# %%
# Ipopt for rectangular ACOPF
ipopt_rec = run_opf(file, ACRPowerModel, Ipopt.Optimizer)
# Out:
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 4 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 4 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 3 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 3 from 360.0 to 60.0 deg.
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      299
# Number of nonzeros in inequality constraint Jacobian.:      124
# Number of nonzeros in Lagrangian Hessian.............:      220
#
# Total number of variables............................:       44
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       28
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       35
# Total number of inequality constraints...............:       26
#         inequality constraints with only lower bounds:       11
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       15
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0059989e+02 3.99e+00 2.88e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  8.2813818e+03 2.47e+00 1.02e+02  -1.0 2.80e+00    -  4.05e-03 3.82e-01h  1
#    2  6.2785390e+03 2.38e+00 9.84e+01  -1.0 2.75e+01    -  5.25e-02 3.43e-02f  1
#    3  5.8775683e+03 2.32e+00 9.46e+01  -1.0 2.04e+01    -  3.13e-01 2.72e-02f  1
#    4  5.4883463e+03 2.07e+00 8.35e+01  -1.0 1.59e+01    -  3.51e-01 1.04e-01f  1
#    5  7.9484559e+03 1.19e+00 4.69e+01  -1.0 1.00e+01    -  8.15e-01 4.25e-01h  1
#    6  8.1567239e+03 1.16e+00 4.87e+01  -1.0 1.03e+01    -  1.09e-01 3.14e-02h  1
#    7  9.2603198e+03 1.02e+00 4.25e+01  -1.0 2.98e+00    -  5.08e-03 1.20e-01h  1
#    8  1.4133666e+04 4.20e-01 1.79e+01  -1.0 2.89e+00    -  7.24e-01 5.87e-01h  1
#    9  1.7475732e+04 1.30e-02 4.54e+00  -1.0 1.14e+00    -  7.63e-01 9.69e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.7589964e+04 4.95e-04 1.55e+00  -1.0 3.27e-01    -  1.00e+00 1.00e+00h  1
#   11  1.7591323e+04 3.66e-05 1.42e-01  -1.0 9.31e-02    -  1.00e+00 1.00e+00h  1
#   12  1.7561513e+04 3.06e-03 4.92e-01  -2.5 2.30e-01    -  8.49e-01 9.49e-01f  1
#   13  1.7552712e+04 3.86e-03 4.84e-01  -2.5 1.40e-01    -  1.00e+00 1.00e+00h  1
#   14  1.7552878e+04 3.07e-06 6.61e-03  -2.5 8.39e-03    -  1.00e+00 1.00e+00h  1
#   15  1.7552042e+04 5.42e-06 2.09e+00  -3.8 1.22e-02    -  1.00e+00 8.50e-01f  1
#   16  1.7551943e+04 4.22e-07 7.55e-01  -3.8 4.44e-03    -  9.54e-01 1.00e+00f  1
#   17  1.7551943e+04 3.85e-09 5.39e-04  -3.8 4.43e-04    -  1.00e+00 1.00e+00h  1
#   18  1.7551897e+04 3.37e-08 8.85e-01  -5.7 1.33e-03    -  1.00e+00 8.67e-01f  1
#   19  1.7551891e+04 6.15e-10 8.17e-05  -5.7 2.66e-04    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.7551891e+04 5.40e-14 4.42e-09  -5.7 7.98e-07    -  1.00e+00 1.00e+00h  1
#   21  1.7551891e+04 3.41e-12 8.40e-04  -8.6 1.89e-05    -  1.00e+00 9.92e-01f  1
#   22  1.7551891e+04 2.57e-14 2.64e-11  -8.6 1.61e-07    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 22
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.3879727098644327e+02    1.7551890839457730e+04
# Dual infeasibility......:   2.6384989735176642e-11    1.0553995894070657e-09
# Constraint violation....:   1.4530043834781736e-14    2.5687785232264559e-14
# Complementarity.........:   2.5061043560665554e-09    1.0024417424266221e-07
# Overall NLP error.......:   2.5061043560665554e-09    1.0024417424266221e-07
#
#
# Number of objective function evaluations             = 23
# Number of objective gradient evaluations             = 23
# Number of equality constraint evaluations            = 23
# Number of inequality constraint evaluations          = 23
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 23
# Number of Lagrangian Hessian evaluations             = 22
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.044
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# Dict{String,Any} with 8 entries:
#   "solve_time"         => 0.247877
#   "optimizer"          => "Ipopt"
#   "termination_status" => LOCALLY_SOLVED
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 17551.9
#   "solution"           => Dict{String,Any}("baseMVA"=>100,"branch"=>Dict{String…
#   "objective_lb"       => -Inf

# %%
# Gurobi nonconvex QP for rectangular ACOPF
pm = instantiate_model(file, ACRPowerModel, PowerModels.build_opf)
set_optimizer_attribute(pm.model, "NonConvex", 2)
grb_rec = optimize_model!(pm, optimizer=Gurobi.Optimizer)
#print(pm.model)
# Out:
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 4 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 4 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 3 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 3 from 360.0 to 60.0 deg.
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 11 rows, 44 columns and 35 nonzeros
# Model fingerprint: 0x61bf915c
# Model has 50 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 2e+02]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+03, 4e+03]
#   Bounds range     [3e-01, 6e+00]
#   RHS range        [1e+00, 4e+00]
#   QRHS range       [8e-01, 2e+01]
# Presolve removed 1 rows and 2 columns
#
# Continuous model is non-convex -- solving as a MIP.
#
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint R1 by 4.000000000
#
# Presolve removed 1 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 150 rows, 69 columns, 476 nonzeros
# Presolved model has 8 quadratic constraint(s)
# Presolved model has 28 bilinear constraint(s)
# Variable types: 69 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 1.039992e+04, 50 iterations, 0.00 seconds
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10399.9158    0   28          - 10399.9158      -     -    0s
#      0     0 10399.9243    0   28          - 10399.9243      -     -    0s
#      0     0 10399.9274    0   28          - 10399.9274      -     -    0s
#      0     0 10399.9274    0   28          - 10399.9274      -     -    0s
#      0     0 10399.9288    0   28          - 10399.9288      -     -    0s
#      0     2 10399.9288    0   28          - 10399.9288      -     -    0s
# *  231   241              32    17616.010491 11472.2975  34.9%  14.0    0s
# *  232   241              32    17616.004605 11472.2975  34.9%  13.9    0s
# *  332   261              29    17614.479595 11472.2975  34.9%  13.5    0s
# * 1182   585              39    17602.988458 16014.9992  9.02%  14.2    0s
# * 1214   529              46    17597.423572 16014.9992  8.99%  14.0    0s
# * 1215   529              46    17597.297481 16014.9992  8.99%  14.0    0s
# * 1221   528              46    17596.579794 16014.9992  8.99%  13.9    0s
# * 1341   520              46    17589.300698 16140.7847  8.24%  14.0    0s
# * 1342   496              46    17577.450998 16140.7847  8.17%  14.0    0s
# * 1510   509              36    17574.951439 16194.0568  7.86%  13.7    0s
# * 1531   522              41    17572.669143 16194.0568  7.85%  13.7    0s
# * 1665   555              41    17572.015901 16315.6227  7.15%  13.5    0s
# * 1666   555              40    17571.869512 16315.6227  7.15%  13.5    0s
# * 1914   563              45    17570.037877 16369.9657  6.83%  13.3    0s
# * 2162   565              41    17568.211784 16626.4792  5.36%  13.1    0s
# * 2163   558              40    17567.684148 16626.4792  5.36%  13.1    0s
# * 2165   555              40    17566.966814 16626.4792  5.35%  13.1    0s
# * 2167   552              41    17566.603457 16626.4792  5.35%  13.1    0s
# * 2616   550              37    17561.078768 16845.9507  4.07%  13.0    0s
# * 2619   550              37    17561.055469 16845.9507  4.07%  13.0    0s
# * 2622   548              37    17560.752029 16845.9507  4.07%  13.0    0s
# * 3460   678              44    17557.008273 16985.9873  3.25%  12.7    1s
# * 5525   680              38    17553.548704 17260.7086  1.67%  12.8    1s
# * 5805   673              48    17553.221633 17281.9309  1.55%  12.7    2s
# * 9788   486              40    17552.708791 17493.7043  0.34%  12.3    3s
# *10188   440              44    17552.382723 17500.3751  0.30%  12.3    3s
# *10198   440              47    17552.348520 17500.3751  0.30%  12.3    3s
# *10204   434              49    17552.303511 17500.3751  0.30%  12.3    3s
# *11346   183              48    17551.916293 17530.6045  0.12%  12.3    3s
# *11844    53              46    17551.900760 17544.8113  0.04%  12.2    3s
# *11857    53              50    17551.793313 17544.8113  0.04%  12.2    3s
# *11864    53              47    17551.605959 17544.8113  0.04%  12.2    3s
# *11871    53              45    17551.582966 17544.8113  0.04%  12.2    3s
#
# Explored 12241 nodes (147334 simplex iterations) in 4.19 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 17551.6 17551.6 17551.8 ... 17553.2
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (4.8110e-04) exceeds tolerance
# Best objective 1.755158296552e+04, best bound 1.755013555451e+04, gap 0.0082%
# Dict{String,Any} with 8 entries:
#   "solve_time"         => 4.19077
#   "optimizer"          => "Gurobi"
#   "termination_status" => OPTIMAL
#   "dual_status"        => NO_SOLUTION
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 17551.6
#   "solution"           => Dict{String,Any}("baseMVA"=>100,"branch"=>Dict{String…
#   "objective_lb"       => 17550.1

# %%
# COSMO for SDP relaxation experiment
cosmo_sdp = run_opf(file, SDPWRMPowerModel, COSMO.Optimizer) # does not support SOC constraints
# Out:
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 4 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 4 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 3 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 3 from 360.0 to 60.0 deg.
# ------------------------------------------------------------------
#           COSMO v0.7.2 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2020
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{74},
#           constraints: A ∈ R^{220x74} (368 nnz),
#           matrix size to factor: 294x294 (1030 nnz)
# Sets:     Nonnegatives of dim: 94
#           ZeroSet of dim: 59
#           DensePsdConeTriangle of dim: 55
#           SecondOrderCone of dim: 3
#           SecondOrderCone of dim: 3
#           SecondOrderCone of dim: 3
#           ... and 2 more
# Settings: ϵ_abs = 1.0e-04, ϵ_rel = 1.0e-04,
#           ϵ_prim_inf = 1.0e-06, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1.0e-6, α = 1.6,
#           max_iter = 2500,
#           scaling iter = 10 (on),
#           check termination every 40 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: CHOLMOD
# Setup Time: 1838.33ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	-9.3854e+07	1.8046e+04	3.1051e+03	1.0000e-01
# 40	2.0221e+04	5.2518e+00	2.1419e+00	1.0000e-01
# 80	1.2235e+04	1.0338e+00	3.5843e+00	5.5180e+00
# 120	9.9608e+03	8.4111e-02	5.7531e+00	4.9516e+01
# 160	9.9616e+03	8.4449e-02	1.1812e+00	4.9516e+01
# 200	1.0571e+04	2.5965e-02	3.1134e+01	5.7984e+02
# 240	1.1353e+04	1.5857e-02	3.2390e+02	5.7984e+02
# 280	1.3635e+04	3.0540e-02	1.1115e+02	5.7984e+02
# 320	1.5661e+04	1.3826e-02	2.7196e+02	5.7984e+02
# 360	1.7119e+04	1.5214e-02	1.4542e+02	5.7984e+02
# 400	1.7292e+04	1.9168e-02	8.8310e+01	5.7984e+02
# 440	1.6920e+04	1.9422e-02	1.3781e+02	5.7984e+02
# 480	1.6076e+04	7.7273e-03	1.1930e+02	5.7984e+02
# 520	1.4630e+04	1.4866e-02	3.4251e+01	1.1190e+02
# 560	1.4589e+04	1.4759e-02	1.1689e+01	1.1190e+02
# 600	1.4844e+04	1.1409e-02	2.1238e+01	1.1190e+02
# 640	1.6049e+04	4.3049e-03	3.3511e+01	1.1190e+02
# 680	1.7018e+04	1.1260e-02	1.5195e+01	1.1190e+02
# 720	1.7028e+04	7.2386e-03	8.8773e+00	1.1190e+02
# 760	1.6340e+04	4.1004e-03	1.3704e+01	1.1190e+02
# 800	1.5677e+04	4.9548e-03	7.3341e+00	1.1190e+02
# 840	1.5591e+04	5.1254e-03	3.3752e+00	1.1190e+02
# 880	1.6031e+04	4.4559e-03	8.7164e+00	1.1190e+02
# 920	1.6496e+04	3.1936e-03	3.7413e+00	1.1190e+02
# 960	1.6600e+04	3.5472e-03	1.9901e+00	1.1190e+02
# 1000	1.6350e+04	3.8575e-03	3.9658e+00	1.1190e+02
# 1040	1.6036e+04	4.1530e-03	2.8217e+00	1.1190e+02
# 1080	1.5934e+04	4.0258e-03	4.6235e-01	1.1190e+02
# 1120	1.6083e+04	3.6639e-03	2.6206e+00	1.1190e+02
# 1160	1.6305e+04	3.5949e-03	2.1366e+00	1.1190e+02
# 1200	1.6400e+04	3.7437e-03	1.3459e-01	1.1190e+02
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 1200
# Optimal objective: 16400.3139
# Runtime: 3.472s (3472.35ms)
# Dict{String,Any} with 8 entries:
#   "solve_time"         => 3.47235
#   "optimizer"          => "COSMO"
#   "termination_status" => OPTIMAL
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 16400.3
#   "solution"           => Dict{String,Any}("baseMVA"=>100,"branch"=>Dict{String…
#   "objective_lb"       => -Inf

# %%
mosek_sdp = run_opf(file, SDPWRMPowerModel, Mosek.Optimizer)
# Out:
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 4 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 4 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 3 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 3 from 360.0 to 60.0 deg.
# ┌ Warning: MathOptInterface.VariablePrimalStart() is not supported by MathOptInterface.Bridges.LazyBridgeOptimizer{MosekModel}. This information will be discarded.
# └ @ MathOptInterface.Utilities /home/weiqizhang/.julia/packages/MathOptInterface/RmalA/src/Utilities/copy.jl:140
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 150
#   Cones                  : 4
#   Scalar variables       : 86
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 30
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 10
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 150
#   Cones                  : 4
#   Scalar variables       : 86
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 86
# Optimizer  - Cones                  : 5
# Optimizer  - Scalar variables       : 60                conic                  : 21
# Optimizer  - Semi-definite variables: 1                 scalarized             : 55
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1924              after factor           : 2232
# Factor     - dense dim.             : 0                 flops                  : 8.85e+04
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   3.0e+00  7.7e+05  1.4e+01  0.00e+00   2.500000000e+04   2.498720000e+04   1.0e+00  0.00
# 1   6.0e-01  1.5e+05  6.2e+00  -1.00e+00  2.465672632e+04   2.464793096e+04   2.0e-01  0.00
# 2   1.4e-02  3.6e+03  9.4e-01  -1.00e+00  6.261206209e+03   6.463368870e+03   4.6e-03  0.00
# 3   2.1e-03  5.4e+02  3.6e-01  -9.95e-01  -9.476544452e+04  -9.339223459e+04  7.0e-04  0.00
# 4   8.4e-04  2.1e+02  1.8e-01  -8.34e-01  -1.173841484e+05  -1.151319740e+05  2.8e-04  0.01
# 5   2.8e-04  7.1e+01  4.7e-02  -1.16e-01  -3.718578626e+04  -3.583716875e+04  9.2e-05  0.01
# 6   9.2e-05  2.3e+01  9.0e-03  6.05e-01   -8.903975451e+03  -8.453259846e+03  3.1e-05  0.01
# 7   2.6e-05  6.7e+00  1.4e-03  9.75e-01   7.296272141e+03   7.430930486e+03   8.7e-06  0.01
# 8   8.3e-06  2.1e+00  2.6e-04  9.58e-01   1.276605970e+04   1.281244403e+04   2.8e-06  0.01
# 9   3.1e-06  7.9e-01  6.3e-05  9.24e-01   1.466289205e+04   1.468255379e+04   1.0e-06  0.01
# 10  1.6e-06  4.1e-01  2.6e-05  9.02e-01   1.521231253e+04   1.522443688e+04   5.4e-07  0.01
# 11  1.3e-06  3.4e-01  2.7e-05  -8.07e-03  1.513855935e+04   1.515776507e+04   4.4e-07  0.01
# 12  1.1e-06  2.9e-01  2.2e-05  2.19e-01   1.531700208e+04   1.533420678e+04   3.8e-07  0.01
# 13  6.1e-07  1.6e-01  9.6e-06  3.53e-01   1.585795039e+04   1.586965236e+04   2.0e-07  0.01
# 14  1.5e-07  3.7e-02  1.1e-06  9.33e-01   1.642431909e+04   1.642700432e+04   4.9e-08  0.01
# 15  5.1e-08  1.3e-02  2.3e-07  9.88e-01   1.655531988e+04   1.655629669e+04   1.7e-08  0.01
# 16  1.4e-08  3.6e-03  3.5e-08  9.96e-01   1.661371374e+04   1.661401664e+04   4.7e-09  0.01
# 17  8.3e-09  4.2e-05  4.5e-11  9.99e-01   1.663529934e+04   1.663530290e+04   5.6e-11  0.01
# 18  6.5e-09  6.8e-07  1.0e-13  1.00e+00   1.663557886e+04   1.663557893e+04   9.4e-13  0.01
# 19  5.5e-09  4.4e-07  5.3e-14  1.00e+00   1.663558108e+04   1.663558113e+04   7.1e-13  0.01
# 20  4.8e-09  2.2e-07  1.9e-14  1.00e+00   1.663558278e+04   1.663558280e+04   3.6e-13  0.01
# 21  4.8e-09  2.2e-07  1.9e-14  1.00e+00   1.663558278e+04   1.663558280e+04   3.6e-13  0.01
# Optimizer terminated. Time: 0.02
# Dict{String,Any} with 8 entries:
#   "solve_time"         => 0.0190089
#   "optimizer"          => "Mosek"
#   "termination_status" => SLOW_PROGRESS
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 16635.6
#   "solution"           => Dict{String,Any}("baseMVA"=>100,"branch"=>Dict{String…
#   "objective_lb"       => 0.0

# %%
grb_soc = run_opf(file, SOCWRPowerModel, Gurobi.Optimizer)
# Out:
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 4 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 4 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 360.0 to 60.0 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 3 from -360.0 to -60.0 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 3 from 360.0 to 60.0 deg.
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 58 rows, 51 columns and 190 nonzeros
# Model fingerprint: 0x6a0db613
# Model has 10 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-01, 2e+02]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+03, 4e+03]
#   Bounds range     [3e-01, 6e+00]
#   RHS range        [2e-01, 4e+00]
#   QRHS range       [6e+00, 2e+01]
# Presolve removed 2 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 112 rows, 64 columns, 265 nonzeros
# Presolved model has 10 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.022e+03
#  Factor NZ  : 1.514e+03
#  Factor Ops : 2.380e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.32090845e+06 -1.00146648e+06  2.61e+01 1.28e+04  1.49e+05     0s
#    1   7.37837601e+05 -1.29152973e+06  5.68e+00 1.41e-02  3.19e+04     0s
#    2   4.85253616e+04 -4.19042808e+05  2.28e-01 5.66e-05  3.56e+03     0s
#    3   2.28401564e+04 -5.48420373e+04  4.20e-02 4.47e-06  5.36e+02     0s
#    4   1.76155268e+04 -9.31021542e+03  1.88e-02 1.37e-06  1.83e+02     0s
#    5   1.58008750e+04  9.22256399e+03  2.78e-04 3.08e-07  4.51e+01     0s
#    6   1.51121066e+04  1.37298761e+04  2.08e-05 6.71e-08  9.47e+00     0s
#    7   1.50507738e+04  1.44796403e+04  7.10e-06 2.74e-08  3.91e+00     0s
#    8   1.50391670e+04  1.47333944e+04  1.65e-06 1.48e-08  2.09e+00     0s
#    9   1.50118415e+04  1.49722562e+04  4.98e-07 5.44e-08  2.71e-01     0s
#   10   1.50037010e+04  1.49966306e+04  3.66e-08 1.46e-08  4.84e-02     0s
#   11   1.49999535e+04  1.49989376e+04  6.86e-10 7.85e-09  6.96e-03     0s
#   12   1.49997639e+04  1.49996324e+04  1.11e-13 1.25e-07  9.01e-04     0s
#   13   1.49997199e+04  1.49997101e+04  1.01e-09 7.78e-08  6.73e-05     0s
#   14   1.49997164e+04  1.49997156e+04  9.50e-11 3.10e-07  5.29e-06     0s
#   15   1.49997161e+04  1.49997160e+04  1.50e-11 5.82e-07  6.92e-07     0s
#
# Barrier solved model in 15 iterations and 0.00 seconds
# Optimal objective 1.49997161e+04
# Dict{String,Any} with 8 entries:
#   "solve_time"         => 0.00237799
#   "optimizer"          => "Gurobi"
#   "termination_status" => OPTIMAL
#   "dual_status"        => NO_SOLUTION
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 14999.7
#   "solution"           => Dict{String,Any}("baseMVA"=>100,"branch"=>Dict{String…
#   "objective_lb"       => -Inf
